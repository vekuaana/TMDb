# %% [markdown]
# # The Movie Database Extraction with API
#
# Extraction of All movies from the movie database (TMDb) for analysis.
#
# Documentation: https://developers.themoviedb.org/3/getting-started/introduction

# %% [markdown]
# ### TMDb API

# %%
import requests
import json
import pandas as pd

# %%
api_key = "6a7a1d7c72791b60828e797ae72b8a50" #the API personal key

total_movies_to_retrieve = 10000 # The number of movies you want to retrieve
movies_per_page = 20 # Retrieve 20 movies per page
max_page_number = 1000 # The maximum number of pages we go through 
current_movie_count = 0 # How many movies are retrieved currently
list_movies_details = [] # List to strore movies with their details

# %%
api_key = "6a7a1d7c72791b60828e797ae72b8a50" #the API personal key

total_movies_to_retrieve = 10000 # The number of movies you want to retrieve
movies_per_page = 20 # Retrieve 20 movies per page
max_page_number = 1000 # The maximum number of pages we go through 
current_movie_count = 0 # How many movies are retrieved currently
list_movies_details = [] # List to strore movies with their details 
# We go through each pages
for page_number in range (1, max_page_number):
    
    # Break if the wanted number of movies retrieved is reached
    if current_movie_count >= total_movies_to_retrieve:
        break
    
    url = "https://api.themoviedb.org/3/movie/top_rated?api_key=" + api_key + "&language=en-US&page=" + str(page_number)
 
    # Make the API request and parse the JSON response
    response = requests.get(url)
    movie_data = json.loads(response.text)
    
    # For each movies of the page, retrieve their details and store them in the list
    for movie in movie_data['results']:
        id = movie['id']
        url_2 = "https://api.themoviedb.org/3/movie/" + str(id) + "?api_key=" + api_key  
        
        response_2 = requests.get(url_2)
        movie_detail = json.loads(response_2.text)
        
        list_movies_details.append(movie_detail)
    current_movie_count = len(list_movies_details)  

# Print the number of movies retrieved
print("Retrieved", len(list_movies_details), "movies.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# OSError: [Errno 65] No route to host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# ProtocolError: ('Connection aborted.', OSError(65, 'No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /var/folders/w2/ytt3rzld1fq08gzv4f1k22zh0000gp/T/ipykernel_19546/103968060.py in <module>
#      24         url_2 = "https://api.themoviedb.org/3/movie/" + str(id) + "?api_key=" + api_key
#      25
# ---> 26         response_2 = requests.get(url_2)
#      27         movie_detail = json.loads(response_2.text)
#      28
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     545
#     546         except (ProtocolError, OSError) as err:
# --> 547             raise ConnectionError(err, request=request)
#     548
#     549         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError(65, 'No route to host'))

# %%
movie_df = pd.DataFrame(list_movies_details) # Convert movies_list to a dataframe

# %%
movie_df
# Out:
#       adult                     backdrop_path  \
# 0     False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg
# 1     False  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg
# 2     False  /ejnlCzBd5pOGAYCpxC93NXSrdrz.jpg
# 3     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg
# 4     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg
# ...     ...                               ...
# 5776  False  /zKsNkKOkgtr0vG8OTBkqtcUhUqp.jpg
# 5777  False  /hExj5Q2lrXZCjZQT0N9j3MHpa9n.jpg
# 5778  False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg
# 5779  False  /x9egVd79MUI7z5PiqHKg4P3r2Lz.jpg
# 5780  False  /rUoGZuscSG4fQP3I56ndadu2A8E.jpg
#
#                                   belongs_to_collection    budget  \
# 0     {'id': 230, 'name': 'The Godfather Collection'...   6000000
# 1                                                  None  25000000
# 2                                                  None         0
# 3     {'id': 230, 'name': 'The Godfather Collection'...  13000000
# 4                                                  None  22000000
# ...                                                 ...       ...
# 5776                                               None         0
# 5777                                               None  11000000
# 5778  {'id': 1041695, 'name': 'R.I.P.D. Collection',...         0
# 5779                                               None         0
# 5780                                               None         0
#
#                                                  genres  \
# 0     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 1     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# ...                                                 ...
# 5776  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 5777  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 5778  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 5779  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 5780  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                                homepage       id     imdb_id  \
# 0                          http://www.thegodfather.com/      238   tt0068646
# 1                                                            278   tt0111161
# 2     https://videocine.com.mx/peliculas/cuando-sea-...   772071  tt12076762
# 3                                                            240   tt0071562
# 4                        http://www.schindlerslist.com/      424   tt0108052
# ...                                                 ...      ...         ...
# 5776               http://www.happygoluckythemovie.com/    10503   tt1045670
# 5777                                                        9768   tt0099329
# 5778                                                     1013860  tt21094994
# 5779                            http://watchermovie.com   807356  tt12004038
# 5780             https://www.netflix.com/title/81253859   729720  tt12808182
#
#      original_language                  original_title  ... release_date  \
# 0                   en                   The Godfather  ...   1972-03-14
# 1                   en        The Shawshank Redemption  ...   1994-09-23
# 2                   es                Cuando Sea Joven  ...   2022-09-14
# 3                   en           The Godfather Part II  ...   1974-12-20
# 4                   en                Schindler's List  ...   1993-12-15
# ...                ...                             ...  ...          ...
# 5776                en                  Happy-Go-Lucky  ...   2008-04-18
# 5777                en                        Cry-Baby  ...   1990-04-05
# 5778                en  R.I.P.D. 2: Rise of the Damned  ...   2022-11-15
# 5779                en                         Watcher  ...   2022-06-03
# 5780                fr           Le Dernier Mercenaire  ...   2021-07-30
#
#         revenue runtime                                   spoken_languages  \
# 0     245066411     175  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      28341469     142  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0     115  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 3     102600000     202  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     321365567     195  [{'english_name': 'German', 'iso_639_1': 'de',...
# ...         ...     ...                                                ...
# 5776   18696602     118  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5777    8266343      85  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5778          0     102  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5779    2667033      96  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5780          0     110  [{'english_name': 'French', 'iso_639_1': 'fr',...
#
#         status                                            tagline  \
# 0     Released                         An offer you can't refuse.
# 1     Released  Fear can hold you prisoner. Hope can set you f...
# 2     Released
# 3     Released  I don't feel I have to wipe everybody out, Tom...
# 4     Released    Whoever saves one life, saves the world entire.
# ...        ...                                                ...
# 5776  Released  The one movie this fall that will put a smile ...
# 5777  Released  Good girls want him bad. Bad girls want him wo...
# 5778  Released                 Meet the new law of the Afterlife.
# 5779  Released                             Evil wants to be seen.
# 5780  Released                    The daddy of all secret agents.
#
#                                title  video vote_average vote_count
# 0                      The Godfather  False        8.711      17774
# 1           The Shawshank Redemption  False        8.701      23626
# 2                   Cuando Sea Joven  False        8.600        213
# 3              The Godfather Part II  False        8.597      10761
# 4                   Schindler's List  False        8.569      13974
# ...                              ...    ...          ...        ...
# 5776                  Happy-Go-Lucky  False        6.569        377
# 5777                        Cry-Baby  False        6.569       1366
# 5778  R.I.P.D. 2: Rise of the Damned  False        6.568        453
# 5779                         Watcher  False        6.568        522
# 5780              The Last Mercenary  False        6.568        545
#
# [5781 rows x 25 columns]
